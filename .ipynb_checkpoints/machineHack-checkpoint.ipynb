# %%
import numpy as np
import pandas as pd

# %%
dfTrain = pd.read_excel('Data_train.xlsx')
dfTest = pd.read_excel('Data_test.xlsx')
dfTrain
# Out:
#       Restaurant                             Location  \
# 0        ID_6321  FTI College, Law College Road, Pune
# 1        ID_2882                 Sector 3, Marathalli
# 2        ID_1595                       Mumbai Central
# 3        ID_5929                      Sector 1, Noida
# 4        ID_6123   Rmz Centennial, I Gate, Whitefield
# ...          ...                                  ...
# 11089    ID_8067        BTM Layout 1, Electronic City
# 11090    ID_4620                     Sector 14, Noida
# 11091    ID_3392                             Majestic
# 11092    ID_4115                 Sector 3, Marathalli
# 11093    ID_4417                   Sector 63A,Gurgaon
#
#                                      Cuisines Average_Cost Minimum_Order  \
# 0      Fast Food, Rolls, Burger, Salad, Wraps         ₹200           ₹50
# 1                         Ice Cream, Desserts         ₹100           ₹50
# 2             Italian, Street Food, Fast Food         ₹150           ₹50
# 3              Mughlai, North Indian, Chinese         ₹250           ₹99
# 4                             Cafe, Beverages         ₹200           ₹99
# ...                                       ...          ...           ...
# 11089    Tibetan, Chinese, Continental, Momos         ₹250           ₹50
# 11090                               Fast Food         ₹100           ₹50
# 11091     South Indian, Chinese, North Indian         ₹100           ₹50
# 11092                            North Indian         ₹100           ₹50
# 11093                            North Indian         ₹100           ₹50
#
#       Rating Votes Reviews Delivery_Time
# 0        3.5    12       4    30 minutes
# 1        3.5    11       4    30 minutes
# 2        3.6    99      30    65 minutes
# 3        3.7   176      95    30 minutes
# 4        3.2   521     235    65 minutes
# ...      ...   ...     ...           ...
# 11089    4.2   326     189    30 minutes
# 11090    3.6    36      16    30 minutes
# 11091    3.5    45      18    30 minutes
# 11092    3.1    24       9    30 minutes
# 11093    NEW     -       -    30 minutes
#
# [11094 rows x 9 columns]

# %%
dfTest
# Out:
#      Restaurant                                    Location  \
# 0       ID_2842  Mico Layout, Stage 2, BTM Layout,Bangalore
# 1        ID_730  Mico Layout, Stage 2, BTM Layout,Bangalore
# 2       ID_4620                             Sector 1, Noida
# 3       ID_5470                  Babarpur, New Delhi, Delhi
# 4       ID_3249                             Sector 1, Noida
# ...         ...                                         ...
# 2769    ID_6342                  Delhi University-GTB Nagar
# 2770    ID_8495  Mico Layout, Stage 2, BTM Layout,Bangalore
# 2771    ID_7122        Noorkhan Bazaar, Malakpet, Hyderabad
# 2772    ID_2475                   D-Block, Sector 63, Noida
# 2773    ID_1595              Dockyard Road, Mumbai CST Area
#
#                                                Cuisines Average_Cost  \
# 0                       North Indian, Chinese, Assamese         ₹350
# 1                                        Biryani, Kebab         ₹100
# 2                                             Fast Food         ₹100
# 3     Mithai, North Indian, Chinese, Fast Food, Sout...         ₹200
# 4                                    Chinese, Fast Food         ₹150
# ...                                                 ...          ...
# 2769                                 Fast Food, Chinese         ₹100
# 2770     Continental, North Indian, Desserts, Beverages         ₹250
# 2771                               Andhra, South Indian         ₹150
# 2772                                             Bakery         ₹100
# 2773                    Italian, Street Food, Fast Food         ₹150
#
#      Minimum_Order Rating Votes Reviews
# 0              ₹50    4.2   361     225
# 1              ₹50    NEW     -       -
# 2              ₹50    3.6    36      16
# 3              ₹50    3.6    66      33
# 4              ₹50    2.9    38      14
# ...            ...    ...   ...     ...
# 2769           ₹50    NEW     -       -
# 2770           ₹50    3.1     5       1
# 2771           ₹50    3.0    16       1
# 2772           ₹99    3.0     7       2
# 2773           ₹50    3.6    99      30
#
# [2774 rows x 8 columns]

# %%
dfTrain['Rating'].replace(to_replace =["NEW","Opening Soon","Temporarily Closed"],
                            value =0,inplace = True)
dfTrain['Rating'].replace(to_replace =["-"],
                            value =-999999,inplace = True)
dfTrain['Rating'] = pd.to_numeric(dfTrain['Rating'])
median = dfTrain.loc[dfTrain['Rating'] > 0, 'Rating'].median()
dfTrain["Rating"] = np.where(dfTrain["Rating"] <= 0, median,dfTrain['Rating'])

# %%
dfTest['Rating'].replace(to_replace =["NEW","Opening Soon","Temporarily Closed"],
                            value =0,inplace = True)
dfTest['Rating'].replace(to_replace =["-"],
                            value =-999999,inplace = True)
dfTest['Rating'] = pd.to_numeric(dfTest['Rating'])
median = dfTest.loc[dfTest['Rating'] > 0, 'Rating'].median()
dfTest["Rating"] = np.where(dfTest["Rating"] <= 0, median,dfTest['Rating'])

# %%
dfTrain['Votes'].replace(to_replace =["-"],
                            value =-999999,inplace = True)
dfTrain['Votes'] = pd.to_numeric(dfTrain['Votes'])

median = dfTrain.loc[dfTrain['Votes'] > 0, 'Votes'].median()
dfTrain["Votes"] = np.where(dfTrain["Votes"] <= 0, median,dfTrain['Votes'])

# %%
dfTest['Votes'].replace(to_replace =["-"],
                            value =-999999,inplace = True)
dfTest['Votes'] = pd.to_numeric(dfTest['Votes'])

median = dfTest.loc[dfTest['Votes'] > 0, 'Votes'].median()
dfTest["Votes"] = np.where(dfTest["Votes"] <= 0, median,dfTest['Votes'])

# %%
dfTrain['Reviews'].replace(to_replace =["-"],
                            value =-999999,inplace = True)
dfTrain['Reviews'] = pd.to_numeric(dfTrain['Reviews'])

median = dfTrain.loc[dfTrain['Reviews'] > 0, 'Votes'].median()
dfTrain["Reviews"] = np.where(dfTrain["Reviews"] <= 0, median,dfTrain['Reviews'])

# %%
dfTest['Reviews'].replace(to_replace =["-"],
                            value =-999999,inplace = True)
dfTest['Reviews'] = pd.to_numeric(dfTest['Reviews'])

median = dfTest.loc[dfTest['Reviews'] > 0, 'Votes'].median()
dfTest["Reviews"] = np.where(dfTest["Reviews"] <= 0, median,dfTest['Reviews'])

# %%
dfTrain['Minimum_Order'] = dfTrain['Minimum_Order'].apply(lambda x:int(x.strip('₹')))
dfTrain['Average_Cost'] = dfTrain['Average_Cost'].apply(lambda x:(x.strip('₹')))
dfTrain['Average_Cost'] = dfTrain['Average_Cost'].apply(lambda x:int(x.replace(',','')) if x != 'for' else -99)
median = int(dfTrain['Average_Cost'].median())
dfTrain["Average_Cost"] = np.where(dfTrain["Average_Cost"] == 0, median,dfTrain['Average_Cost'])

dfTrain['Delivery_Time'] = dfTrain['Delivery_Time'].apply(lambda x:int(x.strip(' minutes')))

# %%
dfTest['Minimum_Order'] = dfTest['Minimum_Order'].apply(lambda x:int(x.strip('₹')))
dfTest['Average_Cost'] = dfTest['Average_Cost'].apply(lambda x:(x.strip('₹')))
dfTest['Average_Cost'] = dfTest['Average_Cost'].apply(lambda x:int(x.replace(',','')) if x != 'for' else -99)
median = int(dfTest['Average_Cost'].median())
dfTest["Average_Cost"] = np.where(dfTest["Average_Cost"] == 0, median,dfTest['Average_Cost'])

# %%
classifier = KNeighborsClassifier()
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

regr = RandomForestRegressor(max_depth=2, random_state=0,n_estimators=100)


def predict(Location,Features):
    
    cuisines = Features.Cuisines
    cuisines = cuisines.split(', ')
    for i,g in dfTrain.groupby('Location'):
        if i == Location:
            relevantFrame = g
    relevantFrame.drop('Location',axis = 1)
    
    relevantFrame['Cuisine_Score'] = relevantFrame['Cuisines'].apply(lambda x:len(set(x.split(', '))&set(cuisines)))
    X = relevantFrame[['Average_Cost','Minimum_Order','Rating','Votes','Reviews','Cuisine_Score']]
    y = relevantFrame['Delivery_Time']
#     Xtest = frameCleanedTesting[['Average_Cost','Minimum_Order','Rating','Votes','Reviews','Cusines']].to_numpy()
    X = X.to_numpy()
    y = y.to_numpy()
    features = Features.values.tolist()
    features.append(len(cuisines))
    features.pop(0)
#     print(features)
    features = np.array(features).reshape(1,-1)
    results = [] #for multiple classifiers
    
    classifier.fit(X,y)
    output = classifier.predict(features)
    reg = LinearRegression().fit(X, y)
    regr.fit(X, y)
    predict = reg.predict(features)
    predictRF = regr.predict(features)
    print(output,predict,predictRF)
#     return output

# %%
results = []
print(type(dfTest))
for row in range(len(dfTest)):
    Location = dfTest.loc[row,"Location"]
    features = dfTest.iloc[row, 2:]
    predict(Location,features)
#     print(features)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# [30] [37.36222761] [41.07319774]
# [30] [33.26015657] [33.17300049]
# [30] [35.32752266] [33.8918868]
# [30] [32.67973912] [33.40348418]
# [30] [35.99484436] [33.8918868]
# [30] [34.72765304] [33.8619211]
# [30] [40.4903896] [33.45868944]
# [30] [33.54648232] [32.91320318]
# [30] [34.68007556] [33.8918868]
# [30] [36.36296599] [32.85257054]
# [30] [36.87577381] [37.04903187]
# [30] [34.27078678] [32.85257054]
# [30] [36.10157693] [33.8918868]
# [45] [42.16401378] [34.48348189]
# [30] [28.65511627] [41.12438461]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-148-a6022911a536> in <module>
#       4     Location = dfTest.loc[row,"Location"]
#       5     features = dfTest.iloc[row, 2:]
# ----> 6     predict(Location,features)
#       7 #     print(features)
#
# <ipython-input-147-e201dc74aa22> in predict(Location, Features)
#      32     output = classifier.predict(features)
#      33     reg = LinearRegression().fit(X, y)
# ---> 34     regr.fit(X, y)
#      35     predict = reg.predict(features)
#      36     predictRF = regr.predict(features)
#
# d:\python_3.7\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     315             trees = [self._make_estimator(append=False,
#     316                                           random_state=random_state)
# --> 317                      for i in range(n_more_estimators)]
#     318
#     319             # Parallel loop: we prefer the threading backend as the Cython code
#
# d:\python_3.7\lib\site-packages\sklearn\ensemble\forest.py in <listcomp>(.0)
#     315             trees = [self._make_estimator(append=False,
#     316                                           random_state=random_state)
# --> 317                      for i in range(n_more_estimators)]
#     318
#     319             # Parallel loop: we prefer the threading backend as the Cython code
#
# d:\python_3.7\lib\site-packages\sklearn\ensemble\base.py in _make_estimator(self, append, random_state)
#     124         sub-estimators.
#     125         """
# --> 126         estimator = clone(self.base_estimator_)
#     127         estimator.set_params(**{p: getattr(self, p)
#     128                                 for p in self.estimator_params})
#
# d:\python_3.7\lib\site-packages\sklearn\base.py in clone(estimator, safe)
#      60                             % (repr(estimator), type(estimator)))
#      61     klass = estimator.__class__
# ---> 62     new_object_params = estimator.get_params(deep=False)
#      63     for name, param in new_object_params.items():
#      64         new_object_params[name] = clone(param, safe=False)
#
# d:\python_3.7\lib\site-packages\sklearn\base.py in get_params(self, deep)
#     191         out = dict()
#     192         for key in self._get_param_names():
# --> 193             value = getattr(self, key, None)
#     194             if deep and hasattr(value, 'get_params'):
#     195                 deep_items = value.get_params().items()
#
# KeyboardInterrupt:
